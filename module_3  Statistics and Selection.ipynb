# %% [markdown]
# ## Module 3
#
# Hi...
# Welcome
#
# In this module  I introduce some methods for you to find best fetures among all of them to predict prices in best way.

# %%
import pandas as pd
import numpy as np

# %%
path = "cars.csv"
df = pd.read_csv(path)

# %% [markdown]
# There is more than one way to analyze features
#  - We can use some methods like correlatioins.
#  - We can also use visualization methods.

# %% [markdown]
# #### Using Correlation function
#
# By using this method you can see the correlation between features
# for example, we can calculate the correlation between variables  of type "int64" or "float64" using the method "corr":

# %%
df.corr()
# Out:
#                    Unnamed: 0  symboling  normalized-losses  wheel-base  \
# Unnamed: 0           1.000000  -0.149081          -0.242882    0.112710
# symboling           -0.149081   1.000000           0.469772   -0.529145
# normalized-losses   -0.242882   0.469772           1.000000   -0.057068
# wheel-base           0.112710  -0.529145          -0.057068    1.000000
# length               0.159841  -0.364511           0.019433    0.879005
# width                0.037535  -0.237262           0.086961    0.814593
# height               0.237930  -0.542261          -0.377664    0.583789
# curb-weight          0.065873  -0.234743           0.099404    0.787584
# engine-size         -0.046450  -0.112069           0.112362    0.576779
# bore                 0.253091  -0.145667          -0.029867    0.501534
# stroke              -0.181985   0.008244           0.055759    0.144675
# compression-ratio    0.143353  -0.181073          -0.114738    0.249689
# ...

# %% [markdown]
# ## Continuous numerical variables:
#
# Continuous numerical variables are variables that may contain any value within some range. Continuous numerical variables can have the type "int64" or "float64". A great way to visualize these variables is by using scatterplots with fitted lines.
#
# In order to start understanding the (linear) relationship between an individual variable and the price. We can do this by using "regplot", which plots the scatterplot plus the fitted regression line for the data.

# %% [markdown]
# Let's find the scatterplot of "engine-size" and "price"

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Positive linear relationship

# %%
sns.regplot(x = 'engine-size', y = 'price', data = df)
plt.ylim(0,)
# Out:
# (0, 55863.06854397509)

# %% [markdown]
# While engine-size grows price grows too: this indicates a positive direct correlation between these two variables. Engine size seems like a pretty good predictor of price since the regression line is almost a perfect diagonal line. E

# %% [markdown]
# #### also we can use df.corr

# %%
df[['engine-size','price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872337
# price           0.872337  1.000000

# %% [markdown]
# - As correlaction is a number between -1 and 1.
# - If it is near 1 so it is positive correlation.
# - If corr is about -1 it is negative correlation.
# - If corr is about 0 it calls weak correlation.

# %% [markdown]
# ### Negative linear relationship

# %%
sns.regplot(x="highway-mpg", y="price", data=df)

# %% [markdown]
# As the highway-mpg rise, the price decline
# so it shows there is negetive relation between them.

# %%
df[['highway-mpg', 'price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.705115
# price          -0.705115  1.000000

# %% [markdown]
# Here the correlation is about -0.70 it is near -1 as results it is negative relation.

# %% [markdown]
# ### Weak Linear Relationship

# %%
sns.regplot(x="peak-rpm", y="price", data=df)

# %%
df[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101519
# price    -0.101519  1.000000

# %% [markdown]
# It is about 0 so there is weak linear relationship.
# so peak-rpm is not really good feature.

# %% [markdown]
# ## Categorical variables
#
# These are variables that describe a 'characteristic' of a data unit, and are selected from a small group of categories. The categorical variables can have the type "object" or "int64". A good way to visualize categorical variables is by using boxplots.

# %% [markdown]
# Let's look at the relationship between "body-style" and "price".

# %%
sns.boxplot(x="body-style", y="price", data=df)

# %%
sns.boxplot(x="engine-location", y="price", data=df)

# %% [markdown]
# Here we see that the distribution of price between these two engine-location categories, front and rear, are distinct enough to take engine-location as a potential good predictor of price.

# %%
# drive-wheels
sns.boxplot(x="drive-wheels", y="price", data=df)

# %% [markdown]
# ### Statistical Analysis

# %% [markdown]
# you can use statistical analysis to achieve more information about data
# we can do it by df.describe()

# %% [markdown]
# we can actually get the mean, the std, the count of variables, the minimum value, the IQR (Interquartile Range:25%, 50% and 75%)

# %%
df.describe()
# Out:
#        Unnamed: 0   symboling  normalized-losses  wheel-base      length  \
# count  200.000000  200.000000         200.000000  200.000000  200.000000
# mean   102.415000    0.830000         122.000000   98.848000    0.837232
# std     58.931634    1.248557          32.076542    6.038261    0.059333
# min      0.000000   -2.000000          65.000000   86.600000    0.678039
# 25%     52.750000    0.000000         100.250000   94.500000    0.800937
# 50%    102.500000    1.000000         122.000000   97.000000    0.832292
# 75%    153.250000    2.000000         138.250000  102.400000    0.881788
# max    203.000000    3.000000         256.000000  120.900000    1.000000
#
#             width      height  curb-weight  engine-size        bore  \
# count  200.000000  200.000000   200.000000   200.000000  200.000000
# mean     0.915250    0.899523  2555.705000   126.860000    3.330000
# std      0.029207    0.040610   518.594552    41.650501    0.268562
# ...

# %% [markdown]
# ### Value counts

# %% [markdown]
# value counts can help us to understand how many value does we have in our particular column.
# Don’t forget the method "value_counts" only works on Pandas series, not Pandas Dataframes. As a result, we only include one bracket  "df['drive-wheels']" not two brackets "df[['drive-wheels']]".

# %%
df['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     74
# 4wd      8
# Name: drive-wheels, dtype: int64

# %% [markdown]
# Also we can convert it into a dataframe as

# %%
df['drive-wheels'].value_counts().to_frame()
# Out:
#      drive-wheels
# fwd           118
# rwd            74
# 4wd             8

# %% [markdown]
#  Let's repeat the above steps but save the results to the dataframe "engine-location" and rename the column  'engine-location' to 'value_counts'.

# %%
# engine-location as variable
engine_loc_counts = df['engine-location'].value_counts().to_frame()
engine_loc_counts.rename(columns={'engine-location': 'value_counts'}, inplace=True)
engine_loc_counts.index.name = 'engine-location'
engine_loc_counts.head(10)
# Out:
#                  value_counts
# engine-location
# front                     197
# rear                        3

# %% [markdown]
# ### Grouping

# %% [markdown]
# The "groupby" method groups data by different categories. The data is grouped based on one or several variables and analysis is performed on the individual groups.
#
#  For example, let's group by the variable "drive-wheels". We see that there are 3 different categories of drive wheels.

# %% [markdown]
# #### Split Data into Groups

# %% [markdown]
# Pandas object can be split into any of their objects. There are multiple ways to split an object like −

# %% [markdown]
#     obj.groupby('key')
#     obj.groupby(['key1','key2'])
#     obj.groupby(key,axis=1)

# %%
df.groupby('engine-size')
df.groupby(['engine-size','price'])

# %% [markdown]
#  we can select the columns 'drive-wheels','body-style' and 'price' , then assign it to the variable "df_group_one".

# %%
df_group_one=df[['drive-wheels','body-style','price']]

# %%
df_group_one
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  16500.0
# 1            rwd    hatchback  16500.0
# 2            fwd        sedan  13950.0
# 3            4wd        sedan  17450.0
# 4            fwd        sedan  15250.0
# 5            fwd        sedan  17710.0
# 6            fwd        wagon  18920.0
# 7            fwd        sedan  23875.0
# 8            rwd        sedan  16430.0
# 9            rwd        sedan  16925.0
# 10           rwd        sedan  20970.0
# 11           rwd        sedan  21105.0
# 12           rwd        sedan  24565.0
# 13           rwd        sedan  30760.0
# 14           rwd        sedan  41315.0
# 15           rwd        sedan  36880.0
# 16           fwd    hatchback   5151.0
# 17           fwd    hatchback   6295.0
# 18           fwd        sedan   6575.0
# 19           fwd    hatchback   5572.0
# 20           fwd    hatchback   6377.0
# 21           fwd    hatchback   7957.0
# 22           fwd    hatchback   6229.0
# ...

# %%
df_group_one=df_group_one.groupby(['drive-wheels'],as_index= False).mean()
df_group_one
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19842.243243

# %%
import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# ### What are correlation and causation and how are they different?

# %% [markdown]
# Two or more variables considered to be related, in a statistical context, if their values change so that as the value of one variable increases or decreases so does the value of the other variable (although it may be in the opposite direction).
#
# For example, for the two variables "hours worked" and "income earned" there is a relationship between the two if the increase in hours worked is associated with an increase in income earned. If we consider the two variables "price" and "purchasing power", as the price of goods increases a person's ability to buy these goods decreases (assuming a constant income).
#
#
# Correlation is a statistical measure (expressed as a number) that describes the size and direction of a relationship between two or more variables. A correlation between variables, however, does not automatically mean that the change in one variable is the cause of the change in the values of the other variable.
#
#
# Causation indicates that one event is the result of the occurrence of the other event; i.e. there is a causal relationship between the two events. This is also referred to as cause and effect.
#
#
# Theoretically, the difference between the two types of relationships are easy to identify — an action or occurrence can cause another (e.g. smoking causes an increase in the risk of developing lung cancer), or it can correlate with another (e.g. smoking is correlated with alcoholism, but it does not cause alcoholism). In practice, however, it remains difficult to clearly establish cause and effect, compared with establishing correlation.

# %% [markdown]
# ### Why are correlation and causation important?

# %% [markdown]
# The objective of much research or scientific analysis is to identify the extent to which one variable relates to another variable. For example:
#
#    - Is there a relationship between a person's education level and their health?
#    - Is pet ownership associated with living longer?
#    - Did a company's marketing campaign increase their product sales?
#
#
# These and other questions are exploring whether a correlation exists between the two variables, and if there is a correlation then this may guide further research into investigating whether one action causes the other. By understanding correlation and causality, it allows for policies and programs that aim to bring about a desired outcome to be better targeted.

# %% [markdown]
# ## Pearson Correlation
# The Pearson Correlation measures the linear dependence between two variables X and Y.
# The resulting coefficient is a value between -1 and 1 inclusive, where:
# - **1**: total positive linear correlation,
# - **0**: no linear correlation, the two variables most likely do not affect each other
# - **-1**: total negative linear correlation.

# %% [markdown]
# **P-value**:
# What is this P-value? The P-value is the probability value that the correlation between these two variables is statistically significant. Normally, we choose a significance level of 0.05, which means that we are 95% confident that the correlation between the variables is significant.
#
# By convention, when the
# - p-value is < 0.001 we say there is strong evidence that the correlation is significant,
# - the p-value is < 0.05; there is moderate evidence that the correlation is significant,
# - the p-value is < 0.1; there is weak evidence that the correlation is significant, and
# - the p-value is > 0.1; there is no evidence that the correlation is significant.

# %% [markdown]
#  We can obtain this information using  "stats" module in the "scipy"  library.

# %%
from scipy import stats

# %% [markdown]
#  Let's calculate the  Pearson Correlation Coefficient and P-value of 'wheel-base' and 'price'.

# %%
pearson_coef, p_value = stats.pearsonr(df['wheel-base'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5891470005448702  with a P-value of P = 4.4570195020502404e-20

# %% [markdown]
# ### Width vs Price

# %% [markdown]
#  Let's calculate the Pearson Correlation Coefficient and P-value of 'width' and 'price':

# %%
pearson_coef, p_value = stats.pearsonr(df['width'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value )
# Out:
# The Pearson Correlation Coefficient is 0.752794863183261  with a P-value of P = 8.256714148308006e-38

# %% [markdown]
# ##### Conclusion:
#
# Since the p-value is < 0.001, the correlation between width and price is statistically significant, and the linear relationship is quite strong (~0.751).

# %% [markdown]
# ### ANOVA

# %% [markdown]
# Analysis of Variance (ANOVA) is probably one of the most popular and commonly used statistical procedures. In this course, Professor Conway will cover the essentials of ANOVA such as one-way between groups ANOVA, post-hoc tests, and repeated measures ANOVA.

# %% [markdown]
# **F-test score**: ANOVA assumes the means of all groups are the same, calculates how much the actual means deviate from the assumption, and reports it as the F-test score. A larger score means there is a larger difference between the means.
#
# **P-value**:  P-value tells how statistically significant is our calculated score value

# %%
df_gptest=df[['drive-wheels','body-style','price']]

grouped_test2=df_gptest[['drive-wheels','price']].groupby(['drive-wheels'])
grouped_test2.head(2)
# Out:
#     drive-wheels    price
# 0            rwd  16500.0
# 1            rwd  16500.0
# 2            fwd  13950.0
# 3            4wd  17450.0
# 4            fwd  15250.0
# 135          4wd   7603.0

# %% [markdown]
#  We can obtain the values of the method group using the method "get_group".

# %%
grouped_test2.get_group('4wd')['price']
# Out:
# 3      17450.0
# 135     7603.0
# 139     9233.0
# 140    11259.0
# 143     8013.0
# 144    11694.0
# 149     7898.0
# 150     8778.0
# Name: price, dtype: float64

# %% [markdown]
# we can use the function 'f_oneway' in the module 'stats'  to obtain the **F-test score** and **P-value**.

# %%
# ANOVA
f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'], grouped_test2.get_group('4wd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 68.49603532807176 , P = 2.6116313994533863e-23

# %% [markdown]
# ### Write queries and selection in pandas

# %% [markdown]
# pd.DataFrame.loc can take one or two indexers. For the rest of the post, I'll represent the first indexer as i and the second indexer as j.
#
# If only one indexer is provided, it applies to the index of the dataframe and the missing indexer is assumed to represent all columns. So the following two examples are equivalent.

# %% [markdown]
#  - df.loc[i]
#  - df.loc[i, :]

# %% [markdown]
# Where : is used to represent all columns.
# If both indexers are present, i references index values and j references column values.

# %% [markdown]
# for this purpose it is better to set index in df to select easier.

# %%
df.set_index('make', inplace = True)
df.head()
# Out:
#              Unnamed: 0  symboling  normalized-losses aspiration num-of-doors  \
# make
# alfa-romero           0          3                122        std          two
# alfa-romero           1          1                122        std          two
# audi                  2          2                164        std         four
# audi                  3          2                164        std         four
# audi                  4          2                122        std          two
#
#               body-style drive-wheels engine-location  wheel-base    length  \
# make
# alfa-romero  convertible          rwd           front        88.6  0.811148
# alfa-romero    hatchback          rwd           front        94.5  0.822681
# audi               sedan          fwd           front        99.8  0.848630
# audi               sedan          4wd           front        99.4  0.848630
# audi               sedan          fwd           front        99.8  0.851994
#
# ...

# %%
df.loc[['alfa-romero', 'audi']]
# Out:
#              Unnamed: 0  symboling  normalized-losses aspiration num-of-doors  \
# make
# alfa-romero           0          3                122        std          two
# alfa-romero           1          1                122        std          two
# audi                  2          2                164        std         four
# audi                  3          2                164        std         four
# audi                  4          2                122        std          two
# audi                  5          1                158        std         four
# audi                  6          1                122        std         four
# audi                  7          1                158      turbo         four
#
#               body-style drive-wheels engine-location  wheel-base    length  \
# make
# alfa-romero  convertible          rwd           front        88.6  0.811148
# alfa-romero    hatchback          rwd           front        94.5  0.822681
# ...

# %% [markdown]
# Here we get only the rows which consists of alfa-romero and audi cars

# %%
df.loc['alfa-romero', 'symboling']
# Out:
# make
# alfa-romero    3
# alfa-romero    1
# Name: symboling, dtype: int64

# %%
df.loc['alfa-romero', 'body-style']
# Out:
# make
# alfa-romero    convertible
# alfa-romero      hatchback
# Name: body-style, dtype: object

# %%
df.loc['audi', 'horsepower-binned']
# Out:
# make
# audi    Medium
# audi    Medium
# audi    Medium
# audi    Medium
# audi    Medium
# audi    Medium
# Name: horsepower-binned, dtype: object

# %% [markdown]
# ### GOOD LOCK
